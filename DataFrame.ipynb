# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ## 以下の表をコピー
# - https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records

# %%
nfl_frame = pd.read_clipboard()
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
# 5     6        Minnesota Vikings    870  470   390    10  0.546
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East
# 5              1961  NFC North

# %%
# 列の名前を確認
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
# 個別のデータにアクセス
nfl_frame['Team']
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2              Chicago Bears
# 3             Miami Dolphins
# 4    New England Patriots[b]
# 5          Minnesota Vikings
# Name: Team, dtype: object

# %%
# 上記と同じ
nfl_frame.Team
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2              Chicago Bears
# 3             Miami Dolphins
# 4    New England Patriots[b]
# 5          Minnesota Vikings
# Name: Team, dtype: object

# %%
# 複数の列にアクセス
nfl_frame[['Team', 'GP']]
# Out:
#                       Team     GP
# 0           Dallas Cowboys    882
# 1        Green Bay Packers  1,336
# 2            Chicago Bears  1,370
# 3           Miami Dolphins    800
# 4  New England Patriots[b]    884
# 5        Minnesota Vikings    870

# %%
# 新しいデータフレームを作成
DataFrame(nfl_frame, columns=['Team', 'GP'])
# Out:
#                       Team     GP
# 0           Dallas Cowboys    882
# 1        Green Bay Packers  1,336
# 2            Chicago Bears  1,370
# 3           Miami Dolphins    800
# 4  New England Patriots[b]    884
# 5        Minnesota Vikings    870

# %%
# 存在しないカラムを指定するとNaNになる
DataFrame(nfl_frame, columns=['Team', 'GP', 'Stadium'])
# Out:
#                       Team     GP  Stadium
# 0           Dallas Cowboys    882      NaN
# 1        Green Bay Packers  1,336      NaN
# 2            Chicago Bears  1,370      NaN
# 3           Miami Dolphins    800      NaN
# 4  New England Patriots[b]    884      NaN
# 5        Minnesota Vikings    870      NaN

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
# 5     6        Minnesota Vikings    870  470   390    10  0.546
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East
# 5              1961  NFC North

# %%
# 先頭の5行を抽出
nfl_frame.head()
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East

# %%
# 先頭の3行を抽出
nfl_frame.head(3)
# Out:
#    Rank               Team     GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1     Dallas Cowboys    882  502   374     6  0.573              1960
# 1     2  Green Bay Packers  1,336  737   562    37  0.565              1921
# 2     3      Chicago Bears  1,370  749   579    42  0.562              1920
#
#     Division
# 0   NFC East
# 1  NFC North
# 2  NFC North

# %%
# 最後の5行を抽出
nfl_frame.tail()
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
# 5     6        Minnesota Vikings    870  470   390    10  0.546
#
#    First NFL Season   Division
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East
# 5              1961  NFC North

# %%
# サンプルを表示
nfl_frame.sample()
# Out:
#    Rank            Team   GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 3     4  Miami Dolphins  800  445   351     4  0.559              1966
#
#    Division
# 3  AFC East

# %%
nfl_frame.sample(3)
# Out:
#    Rank               Team     GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 1     2  Green Bay Packers  1,336  737   562    37  0.565              1921
# 3     4     Miami Dolphins    800  445   351     4  0.559              1966
# 2     3      Chicago Bears  1,370  749   579    42  0.562              1920
#
#     Division
# 1  NFC North
# 3   AFC East
# 2  NFC North

# %%
# インデックスでデータにアクセス
nfl_frame.ix[3]
# Out:
# Rank                             4
# Team                Miami Dolphins
# GP                             800
# Won                            445
# Lost                           351
# Tied                             4
# Pct.                         0.559
# First NFL Season              1966
# Division                  AFC East
# Name: 3, dtype: object

# %%
# カラム追加、データ追加
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
# 5     6        Minnesota Vikings    870  470   390    10  0.546
#
#    First NFL Season   Division         Stadium
# 0              1960   NFC East  Levi's Stadium
# 1              1921  NFC North  Levi's Stadium
# 2              1920  NFC North  Levi's Stadium
# 3              1966   AFC East  Levi's Stadium
# 4              1960   AFC East  Levi's Stadium
# 5              1961  NFC North  Levi's Stadium

# %%
# 値の変更
nfl_frame['Stadium'] = np.arange(6)
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
# 5     6        Minnesota Vikings    870  470   390    10  0.546
#
#    First NFL Season   Division  Stadium
# 0              1960   NFC East        0
# 1              1921  NFC North        1
# 2              1920  NFC North        2
# 3              1966   AFC East        3
# 4              1960   AFC East        4
# 5              1961  NFC North        5

# %%
staduim = Series(["Levi's Stadium", "AT&T"], index=[4, 0])
staduim
# Out:
# 4    Levi's Stadium
# 0              AT&T
# dtype: object

# %%
# インデックスに応じて値が入る
nfl_frame['Stadium'] = staduim
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
# 5     6        Minnesota Vikings    870  470   390    10  0.546
#
#    First NFL Season   Division         Stadium
# 0              1960   NFC East            AT&T
# 1              1921  NFC North             NaN
# 2              1920  NFC North             NaN
# 3              1966   AFC East             NaN
# 4              1960   AFC East  Levi's Stadium
# 5              1961  NFC North             NaN

# %%
# 列の削除
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
# 5     6        Minnesota Vikings    870  470   390    10  0.546
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East
# 5              1961  NFC North

# %%
# データフレームを辞書から作る
data = {'city': ['SF', 'LA', 'NYC'], 'population': [837000, 3880000, 8400000]}
data
# Out:
# {'city': ['SF', 'LA', 'NYC'], 'population': [837000, 3880000, 8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   city  population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000
